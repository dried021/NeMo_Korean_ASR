# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
REPO_PATH = "/content/drive/MyDrive/NeMo_Korean_ASR"
os.chdir(REPO_PATH)
# !pwd  # 현재 위치 확인
# Out:
# /content/drive/MyDrive/NeMo_Korean_ASR

# %%
# !git config user.name "dried021"  # 한 번만 설정
# !git config user.email "dried021@gmail.com"  # 한 번만 설정

# %%
# !git pull origin main --rebase
# Out:
# error: cannot pull with rebase: You have unstaged changes.
# error: please commit or stash them.

# %%
# !git add notebooks/git_commit.ipynb

# %%
import os
from dotenv import load_dotenv
env_path = "/content/drive/MyDrive/NeMo_Korean_ASR/.env"

load_dotenv(env_path)

# %cd /content/drive/MyDrive/NeMo_Korean_ASR

# !git commit -m "[0915] Colab_Update files"
# !git push https://{os.environ['GITHUB_TOKEN']}@github.com/dried021/NeMo_Korean_ASR.git HEAD:main
# Out:
# /content
# [main dfc5ac6] [0915] Colab_Update files
#  1 file changed, 1 insertion(+)
#  create mode 100644 notebooks/git_commit.ipynb
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.23 KiB | 66.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/dried021/NeMo_Korean_ASR.git
#    ef711d5..dfc5ac6  HEAD -> main

# %%
import os
from dotenv import load_dotenv
env_path = "/content/drive/MyDrive/NeMo_Korean_ASR/.env"

load_dotenv(env_path)
# %cd /content/drive/MyDrive/NeMo_Korean_ASR


# !git pull origin main --rebase

# !git add .
# !git commit -m "[0915] Colab_Update files"
# !git push https://{os.environ['GITHUB_TOKEN']}@github.com/dried021/NeMo_Korean_ASR.git HEAD:main
